# %%
from fuzzywuzzy import fuzz
import Levenshtein
import jellyfish
import pandas as pd
import operator
from multiprocessing import Pool
from collections import Counter
import re, string
import numpy as np
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # LinkSight Location Matching Algo
#
# Objective: Write a string matching algo that can process 2000 Philippine location in under 2 minutes and return the correct result 95% of the time. Using n-grams method to speed up performance. N-grams are contiguous sequences of n items from a given sample of text or speech. Breaking words and phrases into n-grams is a technique for narrowing the search space for doing fuzzy matching, which is computationally expensive.

# %% [markdown]
# ## Import Philippine Standard Geographic Code reference file

# %%
psgc = pd.read_csv('psgc-locations.csv.gz',compression="gzip")
psgc.candidate_terms = psgc.loc_tuple.str.encode('utf-8').str.split(",").apply(tuple)
psgc.head()
# Out:
#                                     loc_tuple      code         bgy municity  \
# 0                 ilocos norte,prov,012800000  12800000         NaN      NaN
# 1       adams,ilocos norte,municity,012801000  12801000         NaN    ADAMS
# 2  adams pob,adams,ilocos norte,bgy,012801001  12801001  ADAMS POB.    ADAMS
# 3      adams,adams,ilocos norte,bgy,012801001  12801001  ADAMS POB.    ADAMS
# 4     bacarra,ilocos norte,municity,012802000  12802000         NaN  BACARRA
#
#            prov                                   candidate_terms
# 0  ILOCOS NORTE                   (ilocos norte, prov, 012800000)
# 1  ILOCOS NORTE        (adams, ilocos norte, municity, 012801000)
# 2  ILOCOS NORTE  (adams pob, adams, ilocos norte, bgy, 012801001)
# 3  ILOCOS NORTE      (adams, adams, ilocos norte, bgy, 012801001)
# 4  ILOCOS NORTE      (bacarra, ilocos norte, municity, 012802000)

# %%
psgc[psgc.bgy.isnull() & psgc.municity.isnull() & psgc.prov.isnull()]
# Out:
#                                                loc_tuple       code  bgy  \
# 3228              lingayen,pangasinan,municity,015522000   15522000  NaN
# 3229         aliwekwek,lingayen,pangasinan,bgy,015522001   15522001  NaN
# 3230              baay,lingayen,pangasinan,bgy,015522002   15522002  NaN
# 3231       balangobong,lingayen,pangasinan,bgy,015522003   15522003  NaN
# 3232           balococ,lingayen,pangasinan,bgy,015522004   15522004  NaN
# 3233          bantayan,lingayen,pangasinan,bgy,015522006   15522006  NaN
# 3234            basing,lingayen,pangasinan,bgy,015522007   15522007  NaN
# 3235        capandanan,lingayen,pangasinan,bgy,015522008   15522008  NaN
# 3236   domalandan center,lingayen,pangasinan,bgy,0155...   15522009  NaN
# 3237   domalandan east,lingayen,pangasinan,bgy,015522010   15522010  NaN
# 3238   domalandan west,lingayen,pangasinan,bgy,015522011   15522011  NaN
# 3239          dorongan,lingayen,pangasinan,bgy,015522013   15522013  NaN
# 3240             dulag,lingayen,pangasinan,bgy,015522014   15522014  NaN
# 3241           estanza,lingayen,pangasinan,bgy,015522015   15522015  NaN
# 3242             lasip,lingayen,pangasinan,bgy,015522016   15522016  NaN
# 3243      libsong east,lingayen,pangasinan,bgy,015522017   15522017  NaN
# 3244      libsong west,lingayen,pangasinan,bgy,015522018   15522018  NaN
# 3245            malawa,lingayen,pangasinan,bgy,015522019   15522019  NaN
# 3246         malimpuec,lingayen,pangasinan,bgy,015522020   15522020  NaN
# 45473          ruiz,ipil,zamboanga sibugay,bgy,098305038   98305038  NaN
# 45474       makilas,ipil,zamboanga sibugay,bgy,098305039   98305039  NaN
# 45475       caparan,ipil,zamboanga sibugay,bgy,098305040   98305040  NaN
# 45476      domandan,ipil,zamboanga sibugay,bgy,098305041   98305041  NaN
# 45477    doa josefa,ipil,zamboanga sibugay,bgy,098305042   98305042  NaN
# 45478   dona josefa,ipil,zamboanga sibugay,bgy,098305042   98305042  NaN
# 45479         logan,ipil,zamboanga sibugay,bgy,098305043   98305043  NaN
# 45480        maasin,ipil,zamboanga sibugay,bgy,098305044   98305044  NaN
# 47090           tubod,lanao del norte,municity,103522000  103522000  NaN
# 47091      barakanas,tubod,lanao del norte,bgy,103522001  103522001  NaN
# 47092  baris lumangculob,tubod,lanao del norte,bgy,10...  103522002  NaN
# 47093    lumangculob,tubod,lanao del norte,bgy,103522002  103522002  NaN
# 47094          baris,tubod,lanao del norte,bgy,103522002  103522002  NaN
# 47095         bualan,tubod,lanao del norte,bgy,103522003  103522003  NaN
# 47096          bulod,tubod,lanao del norte,bgy,103522004  103522004  NaN
# 47097         camp 5,tubod,lanao del norte,bgy,103522005  103522005  NaN
# 47098         camp v,tubod,lanao del norte,bgy,103522005  103522005  NaN
# 47099         candis,tubod,lanao del norte,bgy,103522006  103522006  NaN
# 47100       caniogan,tubod,lanao del norte,bgy,103522007  103522007  NaN
# 47101         dalama,tubod,lanao del norte,bgy,103522008  103522008  NaN
# 47102  kakai renabor,tubod,lanao del norte,bgy,103522010  103522010  NaN
# 47103     kalilangan,tubod,lanao del norte,bgy,103522011  103522011  NaN
# 47104        licapao,tubod,lanao del norte,bgy,103522012  103522012  NaN
# 47105       malingao,tubod,lanao del norte,bgy,103522014  103522014  NaN
# 47106          palao,tubod,lanao del norte,bgy,103522015  103522015  NaN
# ...                                                  ...        ...  ...
# 49965  bayabas,nabunturan,compostela valley,bgy,11820...  118209027  NaN
# 49966   bukal,nabunturan,compostela valley,bgy,118209028  118209028  NaN
# 63340                    bangued,abra,municity,140101000  140101000  NaN
# 63341                agtangao,bangued,abra,bgy,140101001  140101001  NaN
# 63342                   angad,bangued,abra,bgy,140101002  140101002  NaN
# 63343                 banacao,bangued,abra,bgy,140101003  140101003  NaN
# 63344                  baacao,bangued,abra,bgy,140101003  140101003  NaN
# 63345              bangbangar,bangued,abra,bgy,140101004  140101004  NaN
# 63346                cabuloan,bangued,abra,bgy,140101005  140101005  NaN
# 63347                  calaba,bangued,abra,bgy,140101006  140101006  NaN
# 63348                   calot,bangued,abra,bgy,140101007  140101007  NaN
# 63349            tablac calot,bangued,abra,bgy,140101007  140101007  NaN
# 63350                  tablac,bangued,abra,bgy,140101007  140101007  NaN
# 63351       cosili west buaya,bangued,abra,bgy,140101008  140101008  NaN
# 63352                   buaya,bangued,abra,bgy,140101008  140101008  NaN
# 63353             cosili west,bangued,abra,bgy,140101008  140101008  NaN
# 63354      cosili east proper,bangued,abra,bgy,140101009  140101009  NaN
# 63355             cosili east,bangued,abra,bgy,140101009  140101009  NaN
# 63356                  proper,bangued,abra,bgy,140101009  140101009  NaN
# 63357              dangdangla,bangued,abra,bgy,140101010  140101010  NaN
# 63358                 lingtan,bangued,abra,bgy,140101011  140101011  NaN
# 63359                  lipcan,bangued,abra,bgy,140101012  140101012  NaN
# 63360                  lubong,bangued,abra,bgy,140101013  140101013  NaN
# 63361             macarcarmay,bangued,abra,bgy,140101014  140101014  NaN
# 63362                   maoay,bangued,abra,bgy,140101015  140101015  NaN
# 63363                  macray,bangued,abra,bgy,140101016  140101016  NaN
# 63364                  malita,bangued,abra,bgy,140101017  140101017  NaN
# 63365                   palao,bangued,abra,bgy,140101018  140101018  NaN
# 63366              patucannay,bangued,abra,bgy,140101019  140101019  NaN
# 63367                   sagap,bangued,abra,bgy,140101020  140101020  NaN
# 63368             san antonio,bangued,abra,bgy,140101021  140101021  NaN
# 63369              santa rosa,bangued,abra,bgy,140101022  140101022  NaN
# 63370                 saoatan,bangued,abra,bgy,140101023  140101023  NaN
# 63371                 sappaac,bangued,abra,bgy,140101024  140101024  NaN
# 63372   zone 2 pob consiliman,bangued,abra,bgy,140101025  140101025  NaN
# 63373              consiliman,bangued,abra,bgy,140101025  140101025  NaN
# 63374                  zone 2,bangued,abra,bgy,140101025  140101025  NaN
# 63375                  lalaud,bangued,abra,bgy,140101026  140101026  NaN
# 63376                  zone 3,bangued,abra,bgy,140101026  140101026  NaN
# 63377       zone 3 pob lalaud,bangued,abra,bgy,140101026  140101026  NaN
# 63378             town proper,bangued,abra,bgy,140101027  140101027  NaN
# 63379  zone 4 pob town proper,bangued,abra,bgy,140101027  140101027  NaN
# 63380                  zone 4,bangued,abra,bgy,140101027  140101027  NaN
# 63381   zone 5 pob bo barikir,bangued,abra,bgy,140101028  140101028  NaN
# 63382                  zone 5,bangued,abra,bgy,140101028  140101028  NaN
# 63383              bo barikir,bangued,abra,bgy,140101028  140101028  NaN
# 63384              sinapangan,bangued,abra,bgy,140101029  140101029  NaN
# 63385                  zone 6,bangued,abra,bgy,140101029  140101029  NaN
# 63386   zone 6 pob sinapangan,bangued,abra,bgy,140101029  140101029  NaN
# 63387                  zone 7,bangued,abra,bgy,140101030  140101030  NaN
# 63388                baliling,bangued,abra,bgy,140101030  140101030  NaN
# 63389     zone 7 pob baliling,bangued,abra,bgy,140101030  140101030  NaN
# 63390                  zone 1,bangued,abra,bgy,140101031  140101031  NaN
# 63391                 nalasin,bangued,abra,bgy,140101031  140101031  NaN
# 63392      zone 1 pob nalasin,bangued,abra,bgy,140101031  140101031  NaN
# 64029             la trinidad,benguet,municity,141110000  141110000  NaN
# 64030          alapang,la trinidad,benguet,bgy,141110001  141110001  NaN
# 64031             alno,la trinidad,benguet,bgy,141110002  141110002  NaN
# 64032          ambiong,la trinidad,benguet,bgy,141110003  141110003  NaN
# 64033           bahong,la trinidad,benguet,bgy,141110004  141110004  NaN
# 64034           balili,la trinidad,benguet,bgy,141110005  141110005  NaN
# 64035           beckel,la trinidad,benguet,bgy,141110006  141110006  NaN
# 64036           bineng,la trinidad,benguet,bgy,141110007  141110007  NaN
# 64037            betag,la trinidad,benguet,bgy,141110008  141110008  NaN
# 64038             cruz,la trinidad,benguet,bgy,141110009  141110009  NaN
# 64039            lubas,la trinidad,benguet,bgy,141110010  141110010  NaN
# 64040             pico,la trinidad,benguet,bgy,141110011  141110011  NaN
# 64041              pob,la trinidad,benguet,bgy,141110012  141110012  NaN
# 64042           puguis,la trinidad,benguet,bgy,141110013  141110013  NaN
# 64043           shilan,la trinidad,benguet,bgy,141110014  141110014  NaN
# 64044           tawang,la trinidad,benguet,bgy,141110015  141110015  NaN
# 64045           wangal,la trinidad,benguet,bgy,141110016  141110016  NaN
# 64820                  kabugao,apayao,municity,148104000  148104000  NaN
# 64821               badduat,kabugao,apayao,bgy,148104001  148104001  NaN
# 64822             baliwanan,kabugao,apayao,bgy,148104002  148104002  NaN
# 64823                  bulu,kabugao,apayao,bgy,148104004  148104004  NaN
# 64824                dagara,kabugao,apayao,bgy,148104005  148104005  NaN
# 64825               dibagat,kabugao,apayao,bgy,148104006  148104006  NaN
# 64826             cabetayan,kabugao,apayao,bgy,148104007  148104007  NaN
# 64827             karagawan,kabugao,apayao,bgy,148104008  148104008  NaN
# 64828                 kumao,kabugao,apayao,bgy,148104009  148104009  NaN
# 64829                  laco,kabugao,apayao,bgy,148104010  148104010  NaN
# 64830               liyyeng,kabugao,apayao,bgy,148104011  148104011  NaN
# 64831       lenneng liyyeng,kabugao,apayao,bgy,148104011  148104011  NaN
# 64832               lenneng,kabugao,apayao,bgy,148104011  148104011  NaN
# 64833                 lucab,kabugao,apayao,bgy,148104012  148104012  NaN
# 64834             luttuacan,kabugao,apayao,bgy,148104013  148104013  NaN
# 64835               madatag,kabugao,apayao,bgy,148104014  148104014  NaN
# 64836              madduang,kabugao,apayao,bgy,148104015  148104015  NaN
# 64837               magabta,kabugao,apayao,bgy,148104016  148104016  NaN
# 64838               maragat,kabugao,apayao,bgy,148104017  148104017  NaN
# 64839               musimut,kabugao,apayao,bgy,148104018  148104018  NaN
# 64840          nagbabalayan,kabugao,apayao,bgy,148104019  148104019  NaN
# 64841                   pob,kabugao,apayao,bgy,148104020  148104020  NaN
# 64842              tuyangan,kabugao,apayao,bgy,148104021  148104021  NaN
# 64843                  waga,kabugao,apayao,bgy,148104022  148104022  NaN
# 67787                       jolo,sulu,municity,156602000  156602000  NaN
# 67788                       alat,jolo,sulu,bgy,156602001  156602001  NaN
# 67789                   asturias,jolo,sulu,bgy,156602002  156602002  NaN
# 67790                     busbus,jolo,sulu,bgy,156602003  156602003  NaN
# 67791               chinese pier,jolo,sulu,bgy,156602004  156602004  NaN
# 67792               san raymundo,jolo,sulu,bgy,156602007  156602007  NaN
# 67793                 takuttakut,jolo,sulu,bgy,156602008  156602008  NaN
# 67794                      tulay,jolo,sulu,bgy,156602009  156602009  NaN
# 67795                     walled,jolo,sulu,bgy,156602010  156602010  NaN
# 67796                walled  pob,jolo,sulu,bgy,156602010  156602010  NaN
# 69085      prosperidad,agusan del sur,municity,160306000  160306000  NaN
# 69086    aurora,prosperidad,agusan del sur,bgy,160306001  160306001  NaN
# 69087       awa,prosperidad,agusan del sur,bgy,160306002  160306002  NaN
# 69088   azpetia,prosperidad,agusan del sur,bgy,160306003  160306003  NaN
# 69089    bahbah,prosperidad,agusan del sur,bgy,160306004  160306004  NaN
# 69090  pob bahbah,prosperidad,agusan del sur,bgy,1603...  160306004  NaN
# 69091       pob,prosperidad,agusan del sur,bgy,160306004  160306004  NaN
# 69092  la caridad,prosperidad,agusan del sur,bgy,1603...  160306006  NaN
# 69093  la suerte,prosperidad,agusan del sur,bgy,16030...  160306007  NaN
# 69094  la union,prosperidad,agusan del sur,bgy,160306008  160306008  NaN
# 69095  las navas,prosperidad,agusan del sur,bgy,16030...  160306009  NaN
# 69096  libertad,prosperidad,agusan del sur,bgy,160306010  160306010  NaN
# 69097  los arcos,prosperidad,agusan del sur,bgy,16030...  160306011  NaN
# 69098    lucena,prosperidad,agusan del sur,bgy,160306012  160306012  NaN
# 69099   mabuhay,prosperidad,agusan del sur,bgy,160306013  160306013  NaN
# 69100  magsaysay,prosperidad,agusan del sur,bgy,16030...  160306014  NaN
# 69101    mapaga,prosperidad,agusan del sur,bgy,160306015  160306015  NaN
# 69102  new maug,prosperidad,agusan del sur,bgy,160306016  160306016  NaN
# 69103      napo,prosperidad,agusan del sur,bgy,160306017  160306017  NaN
# 69104   patinay,prosperidad,agusan del sur,bgy,160306018  160306018  NaN
# 69105  salimbogaon,prosperidad,agusan del sur,bgy,160...  160306020  NaN
# 69106  salvacion,prosperidad,agusan del sur,bgy,16030...  160306021  NaN
# 69107  san joaquin,prosperidad,agusan del sur,bgy,160...  160306022  NaN
# 69108  san jose,prosperidad,agusan del sur,bgy,160306023  160306023  NaN
# 69109  san lorenzo,prosperidad,agusan del sur,bgy,160...  160306024  NaN
# 69110  san martin,prosperidad,agusan del sur,bgy,1603...  160306025  NaN
# 69111  san pedro,prosperidad,agusan del sur,bgy,16030...  160306026  NaN
# 69112  san rafael,prosperidad,agusan del sur,bgy,1603...  160306027  NaN
# 69113  san salvador,prosperidad,agusan del sur,bgy,16...  160306029  NaN
# 69114  san vicente,prosperidad,agusan del sur,bgy,160...  160306030  NaN
# 69115  santa irene,prosperidad,agusan del sur,bgy,160...  160306031  NaN
# 69116  santa maria,prosperidad,agusan del sur,bgy,160...  160306032  NaN
# 69117  la perian,prosperidad,agusan del sur,bgy,16030...  160306033  NaN
# 69118  la purisima,prosperidad,agusan del sur,bgy,160...  160306034  NaN
# 69119  san roque,prosperidad,agusan del sur,bgy,16030...  160306035  NaN
# 70404                 boac,marinduque,municity,174001000  174001000  NaN
# 70405                 agot,boac,marinduque,bgy,174001001  174001001  NaN
# 70406          agumaymayan,boac,marinduque,bgy,174001002  174001002  NaN
# 70407             amoingon,boac,marinduque,bgy,174001003  174001003  NaN
# 70408              apitong,boac,marinduque,bgy,174001004  174001004  NaN
# 70766    bgy 3,mamburao,occidental mindoro,bgy,175106010  175106010  NaN
# 70767  pob 3 bgy 3,mamburao,occidental mindoro,bgy,17...  175106010  NaN
# 70768  pob 4 bgy 4,mamburao,occidental mindoro,bgy,17...  175106011  NaN
# 70769    pob 4,mamburao,occidental mindoro,bgy,175106011  175106011  NaN
# 70770    bgy 4,mamburao,occidental mindoro,bgy,175106011  175106011  NaN
# 70771    pob 5,mamburao,occidental mindoro,bgy,175106012  175106012  NaN
# 70772  pob 5 bgy 5,mamburao,occidental mindoro,bgy,17...  175106012  NaN
# 70773    bgy 5,mamburao,occidental mindoro,bgy,175106012  175106012  NaN
# 70774  pob 6 bgy 6,mamburao,occidental mindoro,bgy,17...  175106013  NaN
# 70775    pob 6,mamburao,occidental mindoro,bgy,175106013  175106013  NaN
# 70776    bgy 6,mamburao,occidental mindoro,bgy,175106013  175106013  NaN
# 70777  pob 7 bgy 7,mamburao,occidental mindoro,bgy,17...  175106014  NaN
# 70778    bgy 7,mamburao,occidental mindoro,bgy,175106014  175106014  NaN
# 70779    pob 7,mamburao,occidental mindoro,bgy,175106014  175106014  NaN
# 70780  pob 8 bgy 8,mamburao,occidental mindoro,bgy,17...  175106015  NaN
# 70781    bgy 8,mamburao,occidental mindoro,bgy,175106015  175106015  NaN
# 70782    pob 8,mamburao,occidental mindoro,bgy,175106015  175106015  NaN
#
#       municity prov                                    candidate_terms
# 3228       NaN  NaN        (lingayen, pangasinan, municity, 015522000)
# 3229       NaN  NaN  (aliwekwek, lingayen, pangasinan, bgy, 015522001)
# 3230       NaN  NaN       (baay, lingayen, pangasinan, bgy, 015522002)
# 3231       NaN  NaN  (balangobong, lingayen, pangasinan, bgy, 01552...
# 3232       NaN  NaN    (balococ, lingayen, pangasinan, bgy, 015522004)
# 3233       NaN  NaN   (bantayan, lingayen, pangasinan, bgy, 015522006)
# 3234       NaN  NaN     (basing, lingayen, pangasinan, bgy, 015522007)
# 3235       NaN  NaN  (capandanan, lingayen, pangasinan, bgy, 015522...
# 3236       NaN  NaN  (domalandan center, lingayen, pangasinan, bgy,...
# 3237       NaN  NaN  (domalandan east, lingayen, pangasinan, bgy, 0...
# 3238       NaN  NaN  (domalandan west, lingayen, pangasinan, bgy, 0...
# 3239       NaN  NaN   (dorongan, lingayen, pangasinan, bgy, 015522013)
# 3240       NaN  NaN      (dulag, lingayen, pangasinan, bgy, 015522014)
# 3241       NaN  NaN    (estanza, lingayen, pangasinan, bgy, 015522015)
# 3242       NaN  NaN      (lasip, lingayen, pangasinan, bgy, 015522016)
# 3243       NaN  NaN  (libsong east, lingayen, pangasinan, bgy, 0155...
# 3244       NaN  NaN  (libsong west, lingayen, pangasinan, bgy, 0155...
# 3245       NaN  NaN     (malawa, lingayen, pangasinan, bgy, 015522019)
# 3246       NaN  NaN  (malimpuec, lingayen, pangasinan, bgy, 015522020)
# 3247       NaN  NaN    (maniboc, lingayen, pangasinan, bgy, 015522021)
# 3248       NaN  NaN   (matalava, lingayen, pangasinan, bgy, 015522022)
# 3249       NaN  NaN  (naguelguel, lingayen, pangasinan, bgy, 015522...
# 3250       NaN  NaN    (namolan, lingayen, pangasinan, bgy, 015522025)
# 3251       NaN  NaN  (pangapisan north, lingayen, pangasinan, bgy, ...
# 3252       NaN  NaN  (pangapisan sur, lingayen, pangasinan, bgy, 01...
# 3253       NaN  NaN        (pob, lingayen, pangasinan, bgy, 015522028)
# 3254       NaN  NaN    (quibaol, lingayen, pangasinan, bgy, 015522029)
# 3255       NaN  NaN    (rosario, lingayen, pangasinan, bgy, 015522030)
# 3256       NaN  NaN   (sabangan, lingayen, pangasinan, bgy, 015522031)
# 3257       NaN  NaN   (talogtog, lingayen, pangasinan, bgy, 015522032)
# 3258       NaN  NaN     (tonton, lingayen, pangasinan, bgy, 015522033)
# 3259       NaN  NaN     (tumbar, lingayen, pangasinan, bgy, 015522034)
# 3260       NaN  NaN       (wawa, lingayen, pangasinan, bgy, 015522035)
# 6904       NaN  NaN    (bayombong, nueva vizcaya, municity, 025005000)
# 6905       NaN  NaN  (bonfal east, bayombong, nueva vizcaya, bgy, 0...
# 6906       NaN  NaN  (bonfal proper, bayombong, nueva vizcaya, bgy,...
# 6907       NaN  NaN  (bonfal west, bayombong, nueva vizcaya, bgy, 0...
# 6908       NaN  NaN  (buenavista, bayombong, nueva vizcaya, bgy, 02...
# 6909       NaN  NaN  (vista hills, bayombong, nueva vizcaya, bgy, 0...
# 6910       NaN  NaN  (buenavista vista hills, bayombong, nueva vizc...
# 6911       NaN  NaN  (busilac, bayombong, nueva vizcaya, bgy, 02500...
# 6912       NaN  NaN  (casat, bayombong, nueva vizcaya, bgy, 025005006)
# 6913       NaN  NaN  (la torre north, bayombong, nueva vizcaya, bgy...
# 6914       NaN  NaN  (magapuy, bayombong, nueva vizcaya, bgy, 02500...
# 6915       NaN  NaN  (magsaysay, bayombong, nueva vizcaya, bgy, 025...
# 6916       NaN  NaN  (masoc, bayombong, nueva vizcaya, bgy, 025005011)
# 6917       NaN  NaN  (paitan, bayombong, nueva vizcaya, bgy, 025005...
# 6918       NaN  NaN  (district 1, bayombong, nueva vizcaya, bgy, 02...
# 6919       NaN  NaN  (district i, bayombong, nueva vizcaya, bgy, 02...
# 6920       NaN  NaN  (don domingo maddela pob district i, bayombong...
# 6921       NaN  NaN  (don domingo maddela, bayombong, nueva vizcaya...
# 6922       NaN  NaN  (don tomas maddela, bayombong, nueva vizcaya, ...
# 6923       NaN  NaN  (district 2, bayombong, nueva vizcaya, bgy, 02...
# 6924       NaN  NaN  (don tomas maddela pob district ii, bayombong,...
# 6925       NaN  NaN  (district ii, bayombong, nueva vizcaya, bgy, 0...
# 6926       NaN  NaN  (district iii pob don m perez, bayombong, nuev...
# 6927       NaN  NaN  (district iii, bayombong, nueva vizcaya, bgy, ...
# 6928       NaN  NaN  (district 3, bayombong, nueva vizcaya, bgy, 02...
# 6929       NaN  NaN  (don m perez, bayombong, nueva vizcaya, bgy, 0...
# 6930       NaN  NaN  (district iv pob, bayombong, nueva vizcaya, bg...
# 6931       NaN  NaN  (district 4, bayombong, nueva vizcaya, bgy, 02...
# 6932       NaN  NaN  (district iv, bayombong, nueva vizcaya, bgy, 0...
# 6933       NaN  NaN  (bansing, bayombong, nueva vizcaya, bgy, 02500...
# 6934       NaN  NaN  (cabuaan, bayombong, nueva vizcaya, bgy, 02500...
# 6935       NaN  NaN  (don mariano marcos, bayombong, nueva vizcaya,...
# 6936       NaN  NaN  (ipilcuneg, bayombong, nueva vizcaya, bgy, 025...
# 6937       NaN  NaN  (la torre south, bayombong, nueva vizcaya, bgy...
# 6938       NaN  NaN  (luyang, bayombong, nueva vizcaya, bgy, 025005...
# 6939       NaN  NaN  (salvacion, bayombong, nueva vizcaya, bgy, 025...
# 6940       NaN  NaN  (san nicolas north luyang, bayombong, nueva vi...
# 6941       NaN  NaN  (san nicolas north, bayombong, nueva vizcaya, ...
# 6942       NaN  NaN  (luyang, bayombong, nueva vizcaya, bgy, 025005...
# 6943       NaN  NaN  (santa rosa, bayombong, nueva vizcaya, bgy, 02...
# 6944       NaN  NaN  (vista alegre b baringin, bayombong, nueva viz...
# 6945       NaN  NaN  (b baringin, bayombong, nueva vizcaya, bgy, 02...
# 6946       NaN  NaN  (vista alegre, bayombong, nueva vizcaya, bgy, ...
# 7182       NaN  NaN        (cabarroguis, quirino, municity, 025702000)
# 7183       NaN  NaN     (banuar, cabarroguis, quirino, bgy, 025702001)
# 7184       NaN  NaN     (burgos, cabarroguis, quirino, bgy, 025702002)
# 7185       NaN  NaN   (calaocan, cabarroguis, quirino, bgy, 025702003)
# 7186       NaN  NaN  (del pilar, cabarroguis, quirino, bgy, 025702004)
# 7187       NaN  NaN     (dibibi, cabarroguis, quirino, bgy, 025702005)
# 7188       NaN  NaN       (eden, cabarroguis, quirino, bgy, 025702006)
# 7189       NaN  NaN  (gundaway pob, cabarroguis, quirino, bgy, 0257...
# 7190       NaN  NaN   (gundaway, cabarroguis, quirino, bgy, 025702007)
# 7191       NaN  NaN  (mangandingay pob, cabarroguis, quirino, bgy, ...
# 7192       NaN  NaN  (mangandingay, cabarroguis, quirino, bgy, 0257...
# 7193       NaN  NaN  (san marcos, cabarroguis, quirino, bgy, 025702...
# 7194       NaN  NaN   (villamor, cabarroguis, quirino, bgy, 025702010)
# 7195       NaN  NaN     (zamora, cabarroguis, quirino, bgy, 025702011)
# 7196       NaN  NaN  (villarose, cabarroguis, quirino, bgy, 025702012)
# 7197       NaN  NaN  (villa pena, cabarroguis, quirino, bgy, 025702...
# 7198       NaN  NaN  (capellangan, cabarroguis, quirino, bgy, 02570...
# 7199       NaN  NaN  (villa pea capellangan, cabarroguis, quirino, ...
# 7200       NaN  NaN   (dingasan, cabarroguis, quirino, bgy, 025702014)
# 7201       NaN  NaN      (tucod, cabarroguis, quirino, bgy, 025702015)
# 7202       NaN  NaN      (gomez, cabarroguis, quirino, bgy, 025702016)
# 7203       NaN  NaN  (santo domingo, cabarroguis, quirino, bgy, 025...
# 15312      NaN  NaN          (santa cruz, laguna, municity, 043426000)
# 63375      NaN  NaN            (lalaud, bangued, abra, bgy, 140101026)
# 63376      NaN  NaN            (zone 3, bangued, abra, bgy, 140101026)
# 63377      NaN  NaN  (zone 3 pob lalaud, bangued, abra, bgy, 140101...
# 63378      NaN  NaN       (town proper, bangued, abra, bgy, 140101027)
# 63379      NaN  NaN  (zone 4 pob town proper, bangued, abra, bgy, 1...
# 63380      NaN  NaN            (zone 4, bangued, abra, bgy, 140101027)
# 63381      NaN  NaN  (zone 5 pob bo barikir, bangued, abra, bgy, 14...
# 63382      NaN  NaN            (zone 5, bangued, abra, bgy, 140101028)
# 63383      NaN  NaN        (bo barikir, bangued, abra, bgy, 140101028)
# 63384      NaN  NaN        (sinapangan, bangued, abra, bgy, 140101029)
# 63385      NaN  NaN            (zone 6, bangued, abra, bgy, 140101029)
# 63386      NaN  NaN  (zone 6 pob sinapangan, bangued, abra, bgy, 14...
# 63387      NaN  NaN            (zone 7, bangued, abra, bgy, 140101030)
# 63388      NaN  NaN          (baliling, bangued, abra, bgy, 140101030)
# 63389      NaN  NaN  (zone 7 pob baliling, bangued, abra, bgy, 1401...
# 63390      NaN  NaN            (zone 1, bangued, abra, bgy, 140101031)
# 63391      NaN  NaN           (nalasin, bangued, abra, bgy, 140101031)
# 63392      NaN  NaN  (zone 1 pob nalasin, bangued, abra, bgy, 14010...
# 64029      NaN  NaN        (la trinidad, benguet, municity, 141110000)
# 64030      NaN  NaN    (alapang, la trinidad, benguet, bgy, 141110001)
# 64031      NaN  NaN       (alno, la trinidad, benguet, bgy, 141110002)
# 64032      NaN  NaN    (ambiong, la trinidad, benguet, bgy, 141110003)
# 64033      NaN  NaN     (bahong, la trinidad, benguet, bgy, 141110004)
# 64034      NaN  NaN     (balili, la trinidad, benguet, bgy, 141110005)
# 64035      NaN  NaN     (beckel, la trinidad, benguet, bgy, 141110006)
# 64036      NaN  NaN     (bineng, la trinidad, benguet, bgy, 141110007)
# 64037      NaN  NaN      (betag, la trinidad, benguet, bgy, 141110008)
# 64038      NaN  NaN       (cruz, la trinidad, benguet, bgy, 141110009)
# 64039      NaN  NaN      (lubas, la trinidad, benguet, bgy, 141110010)
# 64040      NaN  NaN       (pico, la trinidad, benguet, bgy, 141110011)
# 64041      NaN  NaN        (pob, la trinidad, benguet, bgy, 141110012)
# 64042      NaN  NaN     (puguis, la trinidad, benguet, bgy, 141110013)
# 64043      NaN  NaN     (shilan, la trinidad, benguet, bgy, 141110014)
# 64044      NaN  NaN     (tawang, la trinidad, benguet, bgy, 141110015)
# 64045      NaN  NaN     (wangal, la trinidad, benguet, bgy, 141110016)
# 64820      NaN  NaN             (kabugao, apayao, municity, 148104000)
# 64821      NaN  NaN         (badduat, kabugao, apayao, bgy, 148104001)
# 64822      NaN  NaN       (baliwanan, kabugao, apayao, bgy, 148104002)
# 64823      NaN  NaN            (bulu, kabugao, apayao, bgy, 148104004)
# 64824      NaN  NaN          (dagara, kabugao, apayao, bgy, 148104005)
# 64825      NaN  NaN         (dibagat, kabugao, apayao, bgy, 148104006)
# 64826      NaN  NaN       (cabetayan, kabugao, apayao, bgy, 148104007)
# 64827      NaN  NaN       (karagawan, kabugao, apayao, bgy, 148104008)
# 64828      NaN  NaN           (kumao, kabugao, apayao, bgy, 148104009)
# 64829      NaN  NaN            (laco, kabugao, apayao, bgy, 148104010)
# 64830      NaN  NaN         (liyyeng, kabugao, apayao, bgy, 148104011)
# 64831      NaN  NaN  (lenneng liyyeng, kabugao, apayao, bgy, 148104...
# 64832      NaN  NaN         (lenneng, kabugao, apayao, bgy, 148104011)
# 64833      NaN  NaN           (lucab, kabugao, apayao, bgy, 148104012)
# 64834      NaN  NaN       (luttuacan, kabugao, apayao, bgy, 148104013)
# 64835      NaN  NaN         (madatag, kabugao, apayao, bgy, 148104014)
# 64836      NaN  NaN        (madduang, kabugao, apayao, bgy, 148104015)
# 64837      NaN  NaN         (magabta, kabugao, apayao, bgy, 148104016)
# 64838      NaN  NaN         (maragat, kabugao, apayao, bgy, 148104017)
# 64839      NaN  NaN         (musimut, kabugao, apayao, bgy, 148104018)
# 64840      NaN  NaN    (nagbabalayan, kabugao, apayao, bgy, 148104019)
# 64841      NaN  NaN             (pob, kabugao, apayao, bgy, 148104020)
# 64842      NaN  NaN        (tuyangan, kabugao, apayao, bgy, 148104021)
# 64843      NaN  NaN            (waga, kabugao, apayao, bgy, 148104022)
# 67787      NaN  NaN                  (jolo, sulu, municity, 156602000)
# 67788      NaN  NaN                 (alat, jolo, sulu, bgy, 156602001)
# 67789      NaN  NaN             (asturias, jolo, sulu, bgy, 156602002)
# 67790      NaN  NaN               (busbus, jolo, sulu, bgy, 156602003)
# 67791      NaN  NaN         (chinese pier, jolo, sulu, bgy, 156602004)
# 67792      NaN  NaN         (san raymundo, jolo, sulu, bgy, 156602007)
# 67793      NaN  NaN           (takuttakut, jolo, sulu, bgy, 156602008)
# 67794      NaN  NaN                (tulay, jolo, sulu, bgy, 156602009)
# 67795      NaN  NaN               (walled, jolo, sulu, bgy, 156602010)
# 67796      NaN  NaN          (walled  pob, jolo, sulu, bgy, 156602010)
# 69085      NaN  NaN  (prosperidad, agusan del sur, municity, 160306...
# 69086      NaN  NaN  (aurora, prosperidad, agusan del sur, bgy, 160...
# 69087      NaN  NaN  (awa, prosperidad, agusan del sur, bgy, 160306...
# 69088      NaN  NaN  (azpetia, prosperidad, agusan del sur, bgy, 16...
# 69089      NaN  NaN  (bahbah, prosperidad, agusan del sur, bgy, 160...
# 69090      NaN  NaN  (pob bahbah, prosperidad, agusan del sur, bgy,...
# 69091      NaN  NaN  (pob, prosperidad, agusan del sur, bgy, 160306...
# 69092      NaN  NaN  (la caridad, prosperidad, agusan del sur, bgy,...
# 69093      NaN  NaN  (la suerte, prosperidad, agusan del sur, bgy, ...
# 69094      NaN  NaN  (la union, prosperidad, agusan del sur, bgy, 1...
# 69095      NaN  NaN  (las navas, prosperidad, agusan del sur, bgy, ...
# 69096      NaN  NaN  (libertad, prosperidad, agusan del sur, bgy, 1...
# 70772      NaN  NaN  (pob 5 bgy 5, mamburao, occidental mindoro, bg...
# 70773      NaN  NaN  (bgy 5, mamburao, occidental mindoro, bgy, 175...
# 70774      NaN  NaN  (pob 6 bgy 6, mamburao, occidental mindoro, bg...
# 70775      NaN  NaN  (pob 6, mamburao, occidental mindoro, bgy, 175...
# 70776      NaN  NaN  (bgy 6, mamburao, occidental mindoro, bgy, 175...
# 70777      NaN  NaN  (pob 7 bgy 7, mamburao, occidental mindoro, bg...
# 70778      NaN  NaN  (bgy 7, mamburao, occidental mindoro, bgy, 175...
# 70779      NaN  NaN  (pob 7, mamburao, occidental mindoro, bgy, 175...
# 70780      NaN  NaN  (pob 8 bgy 8, mamburao, occidental mindoro, bg...
# 70781      NaN  NaN  (bgy 8, mamburao, occidental mindoro, bgy, 175...
# 70782      NaN  NaN  (pob 8, mamburao, occidental mindoro, bgy, 175...
#
# [541 rows x 6 columns]

# %% [markdown]
# ## Create N-Gram Table
#
# Turn the reference file into a dictionary of n-grams and their associated loc-phrases.
#
# The purpose of this is to narrow down the number of candidate terms for fuzzy matching. It takes too long to do fuzzy matching on all 55k+ locations in the reference dataset. Instead, we'll break the lowest level item in each location phrase into 2-part n-grams. We'll then create a dictionary in which the keys are the unique n-grams and the values are all the location phrases that contain at least one instance of the said n-gram in their primary (first) term.

# %%
#Helper function that creates NGrams. does not include spaces

def makeNgram(string,n):
    string = re.sub("[^a-zA-Z0-9]+","",string.lower())
    ngrams = []
    #for n in range(2,n_max+1):
    for i in range(0,len(string)-(n-1)):
        ngram = unicode(string[i:i+n])
        ngrams.append(ngram)
    return list(set(ngrams)) #return only the unique n-grams. the same string can have repeats

# %%
def generate_ngram_table(loc_tuples,n):
    
    # create the dict
    ngram_table = {}
    
    #for each unique location phrase
    
    for loc in loc_tuples:
        
        #take each unique part in that tuple and extract the n-grams
        
        first_item = loc[0]
            
        first_item = re.sub("[^a-zA-Z0-9]+",u"",first_item.lower())
            
        #for each of these parts, extract the n-grams
            
        #for i in range(0,len(first_item)-(n-1)):
            
            #ngram = first_item[i:i+n].lower()
            
        ngrams_in_first_item = makeNgram(first_item, n)

            #if the n-gram is not yet in the table, add it as a new key for which value is empty list
            
        for ngram in ngrams_in_first_item:
            
            if ngram not in ngram_table.keys():
                
                ngram_table[ngram] = {loc}

            else:
                
                ngram_table[ngram].add(loc)
                
    return ngram_table

# %%
loc_phrase_ngram_table = generate_ngram_table(list(psgc.candidate_terms.dropna(how="all").unique()),2)

# %%
len(loc_phrase_ngram_table)
# Out:
# 956

# %% [markdown]
# # Matching algorithm

# %% [markdown]
# There are four functions that work together to produce the matching algo:
#
# **searchThruReference** - Takes a single group of search terms as a tuple, narrows down the candidate matches from the reference file based on those that share common 2-part n-grams with the first term, runs fuzzy matching on these to return best N results based on scoring formula.
# - **Input**: A single tuple of of up to three search terms sorted from lowest to highest administrative level, a n-gram dictionary with candidate matches as values, and N as the number of top N results you want to retrieve. In the search terms, the first item is the name of the lowest administrative item in the list. The last item is always the administrative class of the lowest-level term-- either bgy (barangay), municity (municipality or city), province (prov). Ex: ("Fort Bonifacio","Taguig City","bgy").
# - **Output**: A dataframe with search term, its top N matches and the similarity scores, PSG codes of each.
#
# **searchThruShortlist** - Helper to `searchThruReference`. Calculates the similarity score between each set of search terms and all its candidate matches. Uses multiprocessing to speed up the process.
# - **Input**: A single set of search terms as a tuple and a list of tuples representing its candidate matches.
# - **Output**: A dataframe containing similiarity scores between a single search term and each of its possible matches. Returns a single row is exact match is found.
#
# **scoreMatches** - Helper to `searchThruShortlist`. Provides the formula for calculating similarity score between a single set of search terms and a single candidate match in the reference file.
# - **Input**: A single set of search terms as a tuple and a single candidate as a tuple.
# - **Output**: (search terms, candidate terms, candidate PSG code, similarity score)
#
# **getMatches** - Applies above steps to a list of search strings and returns a dataframe of search terms and each of their top N matches. For exact matches, only returns a single match.
# - **Input**: A list of search tuples, ngram dictionary, number of results you want returned for each near match.
# - **Output**: Dataframe of many search tuples and each of their top 5 matches, PSG codes, similarity scores.

# %%
def searchThruReference(searchTuple,ngram_table,nresults):
    
    possibleMatches = []
    
    # turn the search string into ngrams based on the length of ngrams in the reference table
    
    n = len(ngram_table.keys()[0])
    
    ss_ngrams = []
        
    # get the unique n-grams in the first item in the search tuple
    
    ss_ngrams = set(makeNgram(searchTuple[0],n))
    
    for ngram in list(ss_ngrams):        
        
        # look each n-gram up in the dictionary of n-grams and the candidates that contain them.
        # add the values as possible matches to be scored
        
        if ngram in ngram_table:
            
            possibleMatches += ngram_table[ngram] 

    
    if len(possibleMatches) == 0:
        
        print "Nothing found"
        
        pass
            
    else:
    #eliminate the candidates that have very few n-grams in common with the search terms
    
        threshold = len(ss_ngrams)/3    

        mostPossible = [k for k, v in Counter(possibleMatches).items() if v >= threshold]

        # calculate similarity scores of search terms with each candidate

        results = pd.DataFrame(searchThruShortlist(searchTuple,mostPossible)).rename(columns={0:'source',1:'match',2:'psgc',3:'score'})

        # get the top N results. for candidate matches that are aliases of the same place, keep the highest scoring one

        topresults = results.sort_values(by="score",ascending=False).reset_index(drop=True).drop_duplicates("psgc",keep="first")[:nresults]

        return topresults

# %%
def searchThruShortlist(searchTuple,shortlist):
    
    #find exact matches first
    
    exact_match = [candidate for candidate in shortlist if searchTuple == candidate[:-1]]
    
    if exact_match <> []:
        
        psgc_code = exact_match[0][-1]
        
        #exact matches result in perfect score and a single row returned
        
        return pd.DataFrame([(searchTuple, exact_match[0], psgc_code,100)])
                

    else:

        #pair searchString with each possible match

        candidate_pairs = []
        for candidateTuple in shortlist:
            candidate_pairs.append((searchTuple,candidateTuple))

        #use multiprocessing to run fuzzy matching
        pool2 = Pool(2) 
        results = pool2.map(scoreMatches, candidate_pairs)
        pool2.close()
        pool2.join()

        return results

# %%
def scoreMatches(tuplePairs,firstItemRatioWgt=0.6,otherItemsRatioWgt=.4,admLevelMatchWgt=1.15):
    
    #split both the searchString and candidateString into their name and interlevel components. 

    searchTuple, candidateTuple = tuplePairs
    searchTerms, searchAdm = searchTuple[:-1], searchTuple[-1]
    candidateTuple = tuplePairs[1]
    candidateTerms, candidateAdm, candidateCode = candidateTuple[:-2], candidateTuple[-2], candidateTuple[-1]

    #if a searchString and the candidate have the same administrative level, this improve the resulting score by a multiplier
    admLevelMatchScore = (admLevelMatchWgt if searchAdm == candidateAdm else 1)

    #check on jw distance ratio between the very first items in search term and candidate term
    firstItemRatio = jellyfish.jaro_winkler(unicode(searchTerms[0]),unicode(candidateTerms[0])) * 100
                
    #Create a weighted score for the match with weights for each input.
    
    if len(searchTerms) == 1:
        score = (firstItemRatio*(firstItemRatioWgt+otherItemsRatioWgt)) * admLevelMatchScore/admLevelMatchWgt
    else:
        otherItemsRatio = fuzz.ratio(" ".join(searchTerms[0:])," ".join(candidateTerms[0:]))
        score = ((firstItemRatio*firstItemRatioWgt) + (otherItemsRatio*otherItemsRatioWgt)) * admLevelMatchScore/admLevelMatchWgt
                 
    results = (searchTuple,candidateTuple,candidateCode,score)
    
    return results

# %% [markdown]
# Test on a single string:

# %%
searchThruReference((u"polilio",u"quezon",u"municity"),loc_phrase_ngram_table,10) #shortlist first, then check for exact
# Out:
#                         source  \
# 0  (polilio, quezon, municity)
# 1  (polilio, quezon, municity)
# 2  (polilio, quezon, municity)
# 3  (polilio, quezon, municity)
# 4  (polilio, quezon, municity)
# 5  (polilio, quezon, municity)
# 6  (polilio, quezon, municity)
# 7  (polilio, quezon, municity)
# 8  (polilio, quezon, municity)
# 9  (polilio, quezon, municity)
#
#                                                match       psgc      score
# 0             (polillo, quezon, municity, 045636000)  045636000  93.771429
# 1     (polilio, cabiao, nueva ecija, bgy, 034904023)  034904023  69.565217
# 2               (liliw, laguna, municity, 043410000)  043410000  69.028571
# 3  (polilio, cabanatuan, nueva ecija, bgy, 034903...  034903063  67.826087
# 4          (pilion, polillo, quezon, bgy, 045636013)  045636013  67.701863
# 5      (pola, oriental mindoro, municity, 175210000)  175210000  66.900000
# 6            (pagbilao, quezon, municity, 045630000)  045630000  66.828571
# 7             (polo, mauban, quezon, bgy, 045627024)  045627024  66.173913
# 8             (jomalig, quezon, municity, 045621000)  045621000  65.542857
# 9            (pili, sariaya, quezon, bgy, 045645032)  045645032  64.857143

# %%
searchThruReference((u"agm",u"delfin albano",u"bgy"),loc_phrase_ngram_table,10) #shortlist first, then check for exact
# Out:
#                        source                                          match  \
# 0   (agm, delfin albano, bgy)  (aga, delfin albano, isabela, bgy, 023118001)
# 1   (agm, delfin albano, bgy)     (dagman, araceli, palawan, bgy, 175303004)
# 2   (agm, delfin albano, bgy)       (naguma, faire, cagayan, bgy, 021526021)
# 4   (agm, delfin albano, bgy)         (agsimao, tineg, abra, bgy, 140125001)
# 5   (agm, delfin albano, bgy)    (bagumbayan, locsin, albay, bgy, 050503004)
# 6   (agm, delfin albano, bgy)     (agmailig, libacao, aklan, bgy, 060409001)
# 7   (agm, delfin albano, bgy)       (dagami, maasin, iloilo, bgy, 063029020)
# 8   (agm, delfin albano, bgy)   (bagumbayan, malinao, albay, bgy, 050510022)
# 10  (agm, delfin albano, bgy)      (naguma, calbayog, samar, bgy, 086003107)
# 11  (agm, delfin albano, bgy)      (jaguimit, dueas, iloilo, bgy, 063017024)
#
#          psgc      score
# 0   023118001  77.066667
# 1   175303004  74.800000
# 2   021526021  71.600000
# 4   140125001  71.371429
# 5   050503004  70.000000
# 6   060409001  69.900000
# 7   063029020  69.600000
# 8   050510022  69.600000
# 10  086003107  68.800000
# 11  063017024  68.700000

# %%
searchThruReference((u"fe",u"culasi","antique",u"municity"),loc_phrase_ngram_table,10) #shortlist first, then check for exact
# Out:
#                             source  \
# 0  (fe, culasi, antique, municity)
# 1  (fe, culasi, antique, municity)
# 2  (fe, culasi, antique, municity)
# 3  (fe, culasi, antique, municity)
# 4  (fe, culasi, antique, municity)
# 5  (fe, culasi, antique, municity)
# 6  (fe, culasi, antique, municity)
# 7  (fe, culasi, antique, municity)
# 8  (fe, culasi, antique, municity)
# 9  (fe, culasi, antique, municity)
#
#                                                match       psgc      score
# 0              (fe, culasi, antique, bgy, 060606019)  060606019  86.956522
# 1              (fe, jamindan, capiz, bgy, 061906009)  061906009  68.521739
# 2       (san fernando, masbate, municity, 054118000)  054118000  60.533333
# 3      (san fernando, la union, municity, 013314000)  013314000  60.133333
# 4        (san felipe, zambales, municity, 037110000)  037110000  59.600000
# 5             (ferrol, romblon, municity, 175916000)  175916000  59.466667
# 6  (san fernando, camarines sur, municity, 051732...  051732000  58.133333
# 7         (fely, maconacon, isabela, bgy, 023117003)  023117003  57.739130
# 8  (san fernando, san jose, antique, bgy, 060613028)  060613028  57.507246
# 9  (ferlda, alegria, surigao del norte, bgy, 1667...  166701008  56.231884

# %%
searchThruReference((u"polillo",u"quezon",u"municity"),loc_phrase_ngram_table,10)
# Out:
#                         source                                   match  \
# 0  (polillo, quezon, municity)  (polillo, quezon, municity, 045636000)
#
#         psgc  score
# 0  045636000    100

# %%
def getMatches(searchTupleList,ngram_table,nresults):
    all_matches = []
    for searchTuple in searchTupleList:
        searchTuple = tuple([item.lower() for item in searchTuple])
        searchTupleMatches = pd.DataFrame(searchThruReference(searchTuple,ngram_table,nresults))
        all_matches.append(searchTupleMatches)
#    return all_matches    
    return pd.concat(all_matches,ignore_index=True)

# %%
sample_list = [(u"Ilocos Sur",u"prov"),
               (u"Fort Bonifacio",u"Taguig",u"bgy"),
               (u"Baguio City",u"Benguet",u"city"),
               (u"Dagatan","Lipa", "Batangas", u"prov"),
               (u"Zamboanga City",u"city"),
               (u"Zamboanga Sibugay",u"prov"),
               ("Aga", "Delfin Albano",u"Isabela","bgy"),
               ("Ahin","Ifugao","bgy"),
               ("Santa Catalina","Lubao","Pampanga","bgy"),
               ("Dampalit", "Malabon","bgy"),
               ("San Pablo","Lagun","city"),
               ("Bgy 105","Caloocan","bgy"),
               ("brgy pasong tamo","quezon","bgy"),
               ("Tagaytay","Cavite","bgy")]

# %%
getMatches(sample_list,
           ngram_table=loc_phrase_ngram_table,
           nresults=10)
# Out:
#                                     source  \
# 0                       (ilocos sur, prov)
# 1            (fort bonifacio, taguig, bgy)
# 2             (baguio city, benguet, city)
# 3             (baguio city, benguet, city)
# 4             (baguio city, benguet, city)
# 5             (baguio city, benguet, city)
# 6             (baguio city, benguet, city)
# 7             (baguio city, benguet, city)
# 8             (baguio city, benguet, city)
# 9             (baguio city, benguet, city)
# 10            (baguio city, benguet, city)
# 11            (baguio city, benguet, city)
# 12         (dagatan, lipa, batangas, prov)
# 13         (dagatan, lipa, batangas, prov)
# 14         (dagatan, lipa, batangas, prov)
# 15         (dagatan, lipa, batangas, prov)
# 16         (dagatan, lipa, batangas, prov)
# 17         (dagatan, lipa, batangas, prov)
# 18         (dagatan, lipa, batangas, prov)
# 19         (dagatan, lipa, batangas, prov)
# 20         (dagatan, lipa, batangas, prov)
# 21         (dagatan, lipa, batangas, prov)
# 22                  (zamboanga city, city)
# 23                  (zamboanga city, city)
# 24                  (zamboanga city, city)
# 25                  (zamboanga city, city)
# 26                  (zamboanga city, city)
# 27                  (zamboanga city, city)
# 28                  (zamboanga city, city)
# 29                  (zamboanga city, city)
# 30                  (zamboanga city, city)
# 31                  (zamboanga city, city)
# 32               (zamboanga sibugay, prov)
# 33      (aga, delfin albano, isabela, bgy)
# 34                     (ahin, ifugao, bgy)
# 35                     (ahin, ifugao, bgy)
# 36                     (ahin, ifugao, bgy)
# 37                     (ahin, ifugao, bgy)
# 38                     (ahin, ifugao, bgy)
# 39                     (ahin, ifugao, bgy)
# 40                     (ahin, ifugao, bgy)
# 41                     (ahin, ifugao, bgy)
# 42                     (ahin, ifugao, bgy)
# 43                     (ahin, ifugao, bgy)
# 44  (santa catalina, lubao, pampanga, bgy)
# 45                (dampalit, malabon, bgy)
# 46                (san pablo, lagun, city)
# 47                (san pablo, lagun, city)
# 48                (san pablo, lagun, city)
# 49                (san pablo, lagun, city)
# 50                (san pablo, lagun, city)
# 51                (san pablo, lagun, city)
# 52                (san pablo, lagun, city)
# 53                (san pablo, lagun, city)
# 54                (san pablo, lagun, city)
# 55                (san pablo, lagun, city)
# 56                (bgy 105, caloocan, bgy)
# 57         (brgy pasong tamo, quezon, bgy)
# 58         (brgy pasong tamo, quezon, bgy)
# 59         (brgy pasong tamo, quezon, bgy)
# 60         (brgy pasong tamo, quezon, bgy)
# 61         (brgy pasong tamo, quezon, bgy)
# 62         (brgy pasong tamo, quezon, bgy)
# 63         (brgy pasong tamo, quezon, bgy)
# 64         (brgy pasong tamo, quezon, bgy)
# 65         (brgy pasong tamo, quezon, bgy)
# 66         (brgy pasong tamo, quezon, bgy)
# 67                 (tagaytay, cavite, bgy)
# 68                 (tagaytay, cavite, bgy)
# 69                 (tagaytay, cavite, bgy)
# 70                 (tagaytay, cavite, bgy)
# 71                 (tagaytay, cavite, bgy)
# 72                 (tagaytay, cavite, bgy)
# 73                 (tagaytay, cavite, bgy)
# 74                 (tagaytay, cavite, bgy)
# 75                 (tagaytay, cavite, bgy)
# 76                 (tagaytay, cavite, bgy)
#
#                                                 match       psgc       score
# 42         (hingyon, hingyon, ifugao, bgy, 142709009)  142709009   67.971429
# 43           (bahan, inabanga, bohol, bgy, 071224002)  071224002   67.800000
# 44  (santa catalina, lubao, pampanga, bgy, 035408033)  035408033  100.000000
# 45                (dampalit, malabon, bgy, 137502006)  137502006  100.000000
# 46           (san pablo, laguna, municity, 043424000)  043424000   85.913043
# 47          (san pablo, isabela, municity, 023133000)  023133000   78.260870
# 48      (san pablo, luisiana, laguna, bgy, 043412017)  043412017   78.260870
# 49       (san pablo, ilagan, isabela, bgy, 023114085)  023114085   77.217391
# 50      (san pablo, guagua, pampanga, bgy, 035407022)  035407022   76.521739
# 51      (san pablo, hagonoy, bulacan, bgy, 031409015)  031409015   76.521739
# 52        (san pablo, burauen, leyte, bgy, 083710063)  083710063   75.826087
# 53     (san pablo, balaoan, la union, bgy, 013305033)  013305033   75.826087
# 54        (san pablo, naval, biliran, bgy, 087808015)  087808015   75.826087
# 55       (san pablo, bauan, batangas, bgy, 041006035)  041006035   75.478261
# 56                (bgy 105, caloocan, bgy, 137501105)  137501105  100.000000
# 57              (pasong tamo, quezon, bgy, 137404080)  137404080   83.495455
# 58          (bugasongan, lezo, aklan, bgy, 060408003)  060408003   71.000000
# 59     (bugasongan, tigbauan, iloilo, bgy, 063045024)  063045024   67.000000
# 60            (bagong pagasa, quezon, bgy, 137404009)  137404009   65.884615
# 61             (pasong putik, quezon, bgy, 137404079)  137404079   64.233333
# 62  (bgy 7 kapitan kong, cavite, cavite, bgy, 0421...  042105060   63.800000
# 63    (bagong paraiso, orani, bataan, bgy, 030809001)  030809001   63.172403
# 64  (bgy 51 kamagong, cavite, cavite, bgy, 042105047)  042105047   63.065909
# 65           (bugasong, antique, municity, 060604000)  060604000   62.978261
# 66     (bagong pagasa, perez, quezon, bgy, 045633009)  045633009   62.684615
# 67            (tagaytay, bato, leyte, bgy, 083707030)  083707030   88.400000
# 68        (tagaytay, aniniy, antique, bgy, 060601023)  060601023   87.200000
# 69            (tagaytay, cavite, municity, 042119000)  042119000   86.956522
# 70         (tagaytay, kananga, leyte, bgy, 083726021)  083726021   86.000000
# 71         (tagaytay, camalig, albay, bgy, 050502039)  050502039   86.000000
# 72        (tagaytay, mahaplag, leyte, bgy, 083731022)  083731022   85.200000
# 73        (tagaytay, gubat, sorsogon, bgy, 056208039)  056208039   83.200000
# 74  (tagaytay, talavera, nueva ecija, bgy, 034930056)  034930056   82.000000
# 75         (tagaytay, san juan, abra, bgy, 140122019)  140122019   81.600000
# 76  (tagaytay, siocon, zamboanga del norte, bgy, 0...  097219033   80.800000

# %% [markdown]
# # Notes
#
# ## Advantages of this method:
# - Improved accuracy.
# - Can handle cases of missing location components or misidentified interlevels
#
# ## Disadvantages
#
# - Doesn't work as well when secondary terms are baked into the first term. Ex when "Fort Bonifacio Taguig" is listed as a barangay and mistakenly containst he municipality as well.
#
# ## To do list:
# - Still gotta improve speed
# - Streamline final steps of exporting file
# - Explore using NLTK library which has ready functions for ngrams
