# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import Levenshtein
import jellyfish
import pandas as pd
import operator
from multiprocessing import Pool
from collections import Counter
import re, string
import numpy as np
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # LinkSight Location Matching Algo
#
# Objective: Write a string matching algo that can process 2000 Philippine location in under 2 minutes and return the correct result 95% of the time. Using n-grams method to speed up performance. N-grams are contiguous sequences of n items from a given sample of text or speech. Breaking words and phrases into n-grams is a technique for narrowing the search space for doing fuzzy matching, which is computationally expensive.

# %% [markdown]
# ## Import Philippine Standard Geographic Code reference file

# %%
psgc = pd.read_csv('psgc-locations.csv.gz',compression="gzip")
psgc.candidate_terms = psgc.loc_tuple.str.encode('utf-8').str.split(",").apply(tuple)
psgc.head()
# Out:
#                                     loc_tuple      code         bgy municity  \
# 0                 ilocos norte,prov,012800000  12800000         NaN      NaN
# 1       adams,ilocos norte,municity,012801000  12801000         NaN    ADAMS
# 2  adams pob,adams,ilocos norte,bgy,012801001  12801001  ADAMS POB.    ADAMS
# 3      adams,adams,ilocos norte,bgy,012801001  12801001  ADAMS POB.    ADAMS
# 4     bacarra,ilocos norte,municity,012802000  12802000         NaN  BACARRA
#
#            prov                                   candidate_terms
# 0  ILOCOS NORTE                   (ilocos norte, prov, 012800000)
# 1  ILOCOS NORTE        (adams, ilocos norte, municity, 012801000)
# 2  ILOCOS NORTE  (adams pob, adams, ilocos norte, bgy, 012801001)
# 3  ILOCOS NORTE      (adams, adams, ilocos norte, bgy, 012801001)
# 4  ILOCOS NORTE      (bacarra, ilocos norte, municity, 012802000)

# %% [markdown]
# ## Create N-Gram Table
#
# Turn the reference file into a dictionary of n-grams and their associated loc-phrases.
#
# The purpose of this is to narrow down the number of candidate terms for fuzzy matching. It takes too long to do fuzzy matching on all 55k+ locations in the reference dataset. Instead, we'll break the lowest level item in each location phrase into 2-part n-grams. We'll then create a dictionary in which the keys are the unique n-grams and the values are all the location phrases that contain at least one instance of the said n-gram.

# %%
#Helper function that creates NGrams. does not include spaces

def makeNgram(string,n):
    string = re.sub("[^a-zA-Z0-9]+","",string.lower())
    ngrams = []
    for i in range(0,len(string)-(n-1)):
        ngram = string[i:i+n]
        ngrams.append(ngram)
    return list(set(ngrams)) #return only the unique n-grams. the same string can have repeats

# %%
def generate_ngram_table(loc_tuples,n):
    
    # create the dict
    ngram_table = {}
    
    #for each unique location phrase
    
    for loc in loc_tuples:
        
        #take each unique part in that tuple and extract the n-grams
        
        item = loc[0]
            
        item = re.sub("[^a-zA-Z0-9]+",u"",item.lower())
            
        #for each of these parts, extract the n-grams
            
        for i in range(0,len(item)-(n-1)):
            
            ngram = item[i:i+n].lower()
                
            #if the n-gram is not yet in the table, add it as a new key for which value is empty list
                
            if ngram not in ngram_table.keys():                                       
                ngram_table[ngram] = {loc}
                
            else:
                ngram_table[ngram].add(loc)
                
    return ngram_table

# %%
loc_phrase_ngram_table = generate_ngram_table(list(psgc.candidate_terms.dropna(how="all").unique()),2)

# %%
len(loc_phrase_ngram_table)
# Out:
# 953

# %% [markdown]
# # Matching algorithm

# %% [markdown]
# There are four functions that work together to produce the matching algo:
#
# 1. **searchThruReference** - Takes a searchString then narrows down and scores possible matches based on common n-grams.
#     - searchTuple - a tuple of strings you're trying to match. last item is always the administrative level.
#     - ngram_table - the reference table
#     - nresults - if no exact match found, max N results you want returned
# 2. **searchThruShortlist** - Helper to `searchThruReference`. Applies scoring to top N most likely candidates.
# 3. **scoreMatches** - Helper to `searchThruShortlist`. Scores candidate pairs using various fuzzy ratios.
# 4. **getMatches** - Applies above algo to a list of search strings and returns a dataframe of sources and top N matches.

# %%
def searchThruReference(searchTuple,ngram_table,nresults):
    
    possibleMatches = []
    
    # turn the search string into ngrams based on the length of ngrams in the reference table
    
    n = len(ngram_table.keys()[0])
    
    ss_ngrams = []
        
    # get the unique n-grams in the first item in the search tuple
    
    ss_ngrams = set(makeNgram(searchTuple[0],n))
    
    for ngram in list(ss_ngrams):        
        
        # look each n-gram up in the hash list and add the values as possibleMatches
        
        if ngram in ngram_table:
            
            possibleMatches += ngram_table[ngram]
    
    #eliminate the candidates that have very few n-grams in common with the search terms
    
    threshold = len(ss_ngrams)/3    
    
    mostPossible = [k for k, v in Counter(possibleMatches).items() if v >= threshold]

    # calculate similarity scores of search tuples with each candidate among possible matches
    
    results = pd.DataFrame(searchThruShortlist(searchTuple,mostPossible)).rename(columns={0:'source',1:'match',2:'psgc',3:'score'})
    
    # deduplicate results based on psgc code
    
    topresults = results.sort_values(by="score",ascending=False).reset_index(drop=True).drop_duplicates("psgc",keep="first")[:nresults]
    
    return topresults

# %%
def searchThruShortlist(searchTuple,shortlist):
    
    #find exact matches first
    
    exact_match = [candidate for candidate in shortlist if searchTuple == candidate[:-1]]
    
    if exact_match <> []:
        
        psgc_code = exact_match[0][-1]
        
        #exact matches result in perfect score and a single row returned
        
        return pd.DataFrame([(searchTuple, exact_match[0], psgc_code,100)])
                

    else:

        #pair searchString with each possible match

        candidate_pairs = []
        for candidateTuple in shortlist:
            candidate_pairs.append((searchTuple,candidateTuple))

        #use multiprocessing to run fuzzy matching
        pool2 = Pool(2) 
        results = pool2.map(scoreMatches, candidate_pairs)
        pool2.close()
        pool2.join()

        return results

# %%
def scoreMatches(tuplePairs,firstItemRatioWgt=0.6,otherItemsRatioWgt=.4,admLevelMatchWgt=1.2):
    
    #split both the searchString and candidateString into their name and interlevel components. 

    searchTuple, candidateTuple = tuplePairs
    searchTerms, searchAdm = searchTuple[:-1], searchTuple[-1]
    candidateTuple = tuplePairs[1]
    candidateTerms, candidateAdm, candidateCode = candidateTuple[:-1], candidateTuple[-2], candidateTuple[-1]

    #if a searchString and the candidate have the same administrative level, this improve the resulting score by a multiplier
    admLevelMatchScore = (admLevelMatchWgt if searchAdm == candidateAdm else 1)
    
    #check on set ratio between secondary search terms
    otherItemsRatio = fuzz.ratio(unicode(" ".join(searchTerms[0:])),unicode(" ".join(candidateTerms[0:])))
    
    #check on jw distance ratio between the very first items in searchString and candidateStrings
    firstItemRatio = jellyfish.jaro_winkler(unicode(searchTerms[0]),unicode(candidateTerms[0])) * 100
                
    #Create a weighted score for the match with weights for each input.
    score = (
        ((firstItemRatio*firstItemRatioWgt) + (otherItemsRatio*otherItemsRatioWgt)) / admLevelMatchWgt
        *  admLevelMatchScore
        )
    
    results = (searchTuple,candidateTuple,candidateCode,score)
    return results

# %% [markdown]
# Test on a single string:

# %%
searchThruReference((u"polilio",u"quezon",u"municity"),loc_phrase_ngram_table,10) #shortlist first, then check for exact
# Out:
#                         source  \
# 0  (polilio, quezon, municity)
# 1  (polilio, quezon, municity)
# 2  (polilio, quezon, municity)
# 3  (polilio, quezon, municity)
# 4  (polilio, quezon, municity)
# 5  (polilio, quezon, municity)
# 6  (polilio, quezon, municity)
# 7  (polilio, quezon, municity)
# 8  (polilio, quezon, municity)
# 9  (polilio, quezon, municity)
#
#                                                match       psgc      score
# 0             (polillo, quezon, municity, 045636000)  045636000  84.571429
# 1              (iloilo, iloilo, municity, 063022000)  063022000  66.952381
# 2      (pola, oriental mindoro, municity, 175210000)  175210000  66.500000
# 3     (polilio, cabiao, nueva ecija, bgy, 034904023)  034904023  65.000000
# 4  (polilio, cabanatuan, nueva ecija, bgy, 034903...  034903063  64.000000
# 5               (liliw, laguna, municity, 043410000)  043410000  63.428571
# 6       (poblacion, polillo, quezon, bgy, 045636015)  045636015  62.597884
# 7          (pilion, polillo, quezon, bgy, 045636013)  045636013  62.547619
# 8            (malilipot, albay, municity, 050509000)  050509000  62.196825
# 9         (poblacion, lopez, quezon, bgy, 045622095)  045622095  61.931217

# %%
searchThruReference((u"polillo",u"quezon",u"municity"),loc_phrase_ngram_table,10) #shortlist first, then check for exact
# Out:
#                         source                                   match  \
# 0  (polillo, quezon, municity)  (polillo, quezon, municity, 045636000)
#
#         psgc  score
# 0  045636000    100

# %%
def getMatches(searchTupleList,ngram_table,nresults):
    all_matches = []
    for searchTuple in searchTupleList:
        searchTuple = tuple([item.lower() for item in searchTuple])
        searchTupleMatches = pd.DataFrame(searchThruReference(searchTuple,ngram_table,nresults))
        all_matches.append(searchTupleMatches)
#    return all_matches    
    return pd.concat(all_matches,ignore_index=True).rename(columns={0:'source',1:'match',2:'psgc',3:'firstItemRatio',4:'otherItemsRatio',5:'admLevelMatch',6:'total'})

# %%
sample_list = [(u"Ilocos Sur",u"prov"),
               (u"Fort Bonifacio",u"Taguig",u"bgy"),
               (u"Baguio City",u"Benguet",u"city"),
               (u"Dagatan","Lipa", "Batangas", u"prov"),
               (u"Zamboanga City",u"city"),
               (u"Zamboanga Sibugay",u"prov"),
               ("Aga", "Delfin Albano",u"Isabela","bgy"),
               ("Ahin","Ifugao","bgy"),
               ("Santa Catalina","Lubao","Pampanga","bgy"),
               ("Dampalit", "Malabon","bgy"),
               ("San Pablo","Lagun","city"),
               ("Bgy 105","Caloocan","bgy"),
               ("brgy pasong tamo","quezon","bgy"),
               ("Tagaytay","Cavite","bgy")]

# %%
getMatches(sample_list,
           ngram_table=loc_phrase_ngram_table,
           nresults=5)
# Out:
#                                     source  \
# 0                       (ilocos sur, prov)
# 1            (fort bonifacio, taguig, bgy)
# 2            (fort bonifacio, taguig, bgy)
# 3            (fort bonifacio, taguig, bgy)
# 4            (fort bonifacio, taguig, bgy)
# 5            (fort bonifacio, taguig, bgy)
# 6             (baguio city, benguet, city)
# 7             (baguio city, benguet, city)
# 8             (baguio city, benguet, city)
# 9             (baguio city, benguet, city)
# 10            (baguio city, benguet, city)
# 11         (dagatan, lipa, batangas, prov)
# 12         (dagatan, lipa, batangas, prov)
# 13         (dagatan, lipa, batangas, prov)
# 14         (dagatan, lipa, batangas, prov)
# 15         (dagatan, lipa, batangas, prov)
# 16                  (zamboanga city, city)
# 17                  (zamboanga city, city)
# 18                  (zamboanga city, city)
# 19                  (zamboanga city, city)
# 20                  (zamboanga city, city)
# 21               (zamboanga sibugay, prov)
# 22      (aga, delfin albano, isabela, bgy)
# 23                     (ahin, ifugao, bgy)
# 24                     (ahin, ifugao, bgy)
# 25                     (ahin, ifugao, bgy)
# 26                     (ahin, ifugao, bgy)
# 27                     (ahin, ifugao, bgy)
# 28  (santa catalina, lubao, pampanga, bgy)
# 29                (dampalit, malabon, bgy)
# 30                (dampalit, malabon, bgy)
# 31                (dampalit, malabon, bgy)
# 32                (dampalit, malabon, bgy)
# 33                (dampalit, malabon, bgy)
# 34                (san pablo, lagun, city)
# 35                (san pablo, lagun, city)
# 36                (san pablo, lagun, city)
# 37                (san pablo, lagun, city)
# 38                (san pablo, lagun, city)
# 39                (bgy 105, caloocan, bgy)
# 40                (bgy 105, caloocan, bgy)
# 41                (bgy 105, caloocan, bgy)
# 42                (bgy 105, caloocan, bgy)
# 43                (bgy 105, caloocan, bgy)
# 44         (brgy pasong tamo, quezon, bgy)
# 45         (brgy pasong tamo, quezon, bgy)
# 46         (brgy pasong tamo, quezon, bgy)
# 47         (brgy pasong tamo, quezon, bgy)
# 48         (brgy pasong tamo, quezon, bgy)
# 49                 (tagaytay, cavite, bgy)
# 50                 (tagaytay, cavite, bgy)
# 51                 (tagaytay, cavite, bgy)
# 52                 (tagaytay, cavite, bgy)
# 53                 (tagaytay, cavite, bgy)
#
#                                                 match       psgc       score
# 0                       (ilocos sur, prov, 012900000)  012900000  100.000000
# 1   (fort bonifacio, taguig, ncr fourth district, ...  137607020   85.600000
# 2   (andres bonifacio, baguio, benguet, bgy, 14110...  141102117   72.046104
# 3   (andres bonifacio, javier, leyte, bgy, 083724002)  083724002   70.046104
# 4   (andres bonifacio, diffun, quirino, bgy, 02570...  025703001   69.246104
# 5   (andres bonifacio, san joaquin, iloilo, bgy, 0...  063040002   68.846104
# 6              (baguio, benguet, municity, 141102000)  141102000   67.787879
# 7           (baguio, tayabas, quezon, bgy, 045647013)  045647013   65.121212
# 8              (bagu, bakun, benguet, bgy, 141103002)  141103002   64.636364
# 9           (baguinloc, anao, tarlac, bgy, 036901001)  036901001   60.808081
# 10         (bagunot, baggao, cagayan, bgy, 021506009)  021506009   60.359307
# 11          (dagatan, lipa, batangas, bgy, 041014017)  041014017   80.333333
# 12        (dagatan, taysan, batangas, bgy, 041032004)  041032004   75.000000
# 13      (dagatan, san jose, batangas, bgy, 041022012)  041022012   74.000000
# 14           (dagatan, liliw, laguna, bgy, 043410010)  043410010   70.666667
# 15            (dagatan, badian, cebu, bgy, 072207011)  072207011   69.666667
# 16               (zamboanga sibugay, prov, 098300000)  098300000   67.963585
# 17   (zamboanga, laoag, ilocos norte, bgy, 012812084)  012812084   65.428571
# 18  (zamboanga, zamboanga del sur, municity, 09733...  097332000   65.095238
# 19  (zamboanguita, negros oriental, municity, 0746...  074625000   64.448052
# 20             (zamboanga del norte, prov, 097200000)  097200000   62.979950
# 21               (zamboanga sibugay, prov, 098300000)  098300000  100.000000
# 22      (aga, delfin albano, isabela, bgy, 023118001)  023118001  100.000000
# 23              (ahin, tinoc, ifugao, bgy, 142710001)  142710001   87.600000
# 24          (tahing, calinog, iloilo, bgy, 063013066)  063013066   70.933333
# 25  (ahan, guindulungan, maguindanao, bgy, 153825001)  153825001   68.400000
# 26        (lahing, macalelon, quezon, bgy, 045625006)  045625006   68.133333
# 27             (bahian, loboc, bohol, bgy, 071229004)  071229004   67.733333
# 28  (santa catalina, lubao, pampanga, bgy, 035408033)  035408033  100.000000
# 29  (dampalit, malabon, ncr third district, bgy, 1...  137502006   83.200000
# 30     (dampay, candelaria, zambales, bgy, 037103004)  037103004   74.300000
# 31       (dampol i, pulilan, bulacan, bgy, 031418005)  031418005   74.000000
# 32               (dalit, pilar, abra, bgy, 140119005)  140119005   74.000000
# 33        (dampas, tagbilaran, bohol, bgy, 071242006)  071242006   73.900000
# 34           (san pablo, laguna, municity, 043424000)  043424000   75.000000
# 35          (san pablo, isabela, municity, 023133000)  023133000   72.666667
# 36      (san pablo, luisiana, laguna, bgy, 043412017)  043412017   72.666667
# 37       (san pablo, ilagan, isabela, bgy, 023114085)  023114085   71.666667
# 38      (san pablo, guagua, pampanga, bgy, 035407022)  035407022   71.333333
# 39         (bgy 105, tacloban, leyte, bgy, 083747024)  083747024   84.800000
# 40  (bgy 105, caloocan, ncr third district, bgy, 1...  137501105   83.200000
# 41        (bgy 510, sampaloc, manila, bgy, 133906116)  133906116   82.285714
# 42        (bgy 10, catbalogan, samar, bgy, 086005043)  086005043   82.285714
# 43       (bgy 105, tondo iii, manila, bgy, 133901105)  133901105   82.000000
# 44  (pasong tamo, quezon, ncr second district, bgy...  137404080   70.295455
# 45          (bugasongan, lezo, aklan, bgy, 060408003)  060408003   69.000000
# 46     (bugasongan, tigbauan, iloilo, bgy, 063045024)  063045024   65.400000
# 47  (bgy 7 kapitan kong, cavite, cavite, bgy, 0421...  042105060   62.600000
# 48  (bgy 51 kamagong, cavite, cavite, bgy, 042105047)  042105047   61.865909
# 49            (tagaytay, bato, leyte, bgy, 083707030)  083707030   85.200000
# 50        (tagaytay, aniniy, antique, bgy, 060601023)  060601023   84.800000
# 51         (tagaytay, camalig, albay, bgy, 050502039)  050502039   83.600000
# 52         (tagaytay, kananga, leyte, bgy, 083726021)  083726021   83.600000
# 53        (tagaytay, mahaplag, leyte, bgy, 083731022)  083731022   82.800000

# %% [markdown]
# # Notes
#
# ## Advantages of this method:
# - Improved accuracy.
# - Can handle more edge cases of missing location components or misidentified interlevels
#
# ## To do list:
# - Still gotta improve speed
# - Streamline final steps of exporting file
